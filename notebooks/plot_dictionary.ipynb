# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go

import pandas as pd
import numpy as np

# %%
programming_skills = pd.read_csv("../data/raw/programming_summary_2.csv", index_col=[0])
python_skills = pd.read_csv("../data/raw/python_summary_2.csv", index_col=[0])
tech_skills = pd.read_csv("../data/raw/skills_summary_2.csv", index_col=[0])

# %%
programming_skills["type"] = "programming"
python_skills["type"] = "python"
tech_skills["type"] = "tech"

# %%
skills = pd.concat([programming_skills, python_skills, tech_skills])
skills # .head()
# Out:
#           skill  count         type
# 0        python   2208  programming
# 1         scala    121  programming
# 2    powershell    115  programming
# 3           sql   1810  programming
# 4           c++     87  programming
# 5        pascal     87  programming
# 6             r    517  programming
# 7    javascript    239  programming
# 8           php    205  programming
# 9        matlab    116  programming
# 10         perl    102  programming
# 11        plsql    170  programming
# 12          vba     68  programming
# 13         html     21  programming
# 14           c#     42  programming
# 15         java    192  programming
# 16           go     42  programming
# 17         bash     82  programming
# 18   typescript     14  programming
# 19     assembly     28  programming
# 20          css     42  programming
# 21        nosql     48  programming
# 22        mssql     34  programming
# 23         tsql     34  programming
# 24         ruby     34  programming
# 0       pytorch    155       python
# 1        pandas     68       python
# 2   scikitlearn     68       python
# 3    tensorflow     68       python
# 4        plotly     14       python
# 0       powerbi    325         tech
# 1        hadoop    526         tech
# 2           aws    732         tech
# 3         linux    326         tech
# 4        pandas     68         tech
# 5           sap   2352         tech
# 6         excel    549         tech
# 7          spss     68         tech
# 8       tableau    565         tech
# 9    sharepoint    123         tech
# 10       jquery      7         tech
# 11        spark    364         tech
# 12      airflow    232         tech
# 13         qlik     82         tech
# 14         ssis     14         tech
# 15         word     34         tech
# 16   powerpoint     34         tech
# 17          vue     34         tech
# 18         ssrs     34         tech

# %%
sns.barplot(x = "count", y = "skill", hue = "type", data = skills);
